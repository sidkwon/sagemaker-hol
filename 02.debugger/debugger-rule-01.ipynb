# %% [markdown]
# # SageMaker Debugger rules
#
# Source
# - https://sagemaker.readthedocs.io/en/stable/amazon_sagemaker_debugger.html
# - https://gitlab.com/juliensimon/dlnotebooks/blob/master/keras/05-keras-blog-post/Fashion%20MNIST-SageMaker.ipynb
# - https://github.com/aws/amazon-sagemaker-examples/blob/master/sagemaker-debugger/tensorflow_profiling/tf-resnet-profiling-single-gpu-single-node.ipynb

# %%
# install_needed = True
install_needed = False

# %%
import sys
import IPython

if install_needed:
    print("installing deps and restarting kernel")
    # !{sys.executable} -m pip install -U 'sagemaker[local]'
    # !{sys.executable} -m pip install -U sagemaker-experiments # SageMaker Experiments SDK 
    # !{sys.executable} -m pip install -U sagemaker             # SageMaker Python SDK
#     !/bin/bash ./local/local_mode_setup.sh
    IPython.Application.instance().kernel.do_shutdown(True)

# %%
# from IPython.display import Image
# Image("fashion-mnist-sprite.png")

# %%
import sagemaker

from smexperiments.experiment import Experiment ### SM Experiment
from smexperiments.trial import Trial           ### SM Experiment

from sagemaker.debugger import (
    Rule,
    DebuggerHookConfig,
    TensorBoardOutputConfig,
    CollectionConfig,
    rule_configs,
    ProfilerRule
)

from time import strftime

import boto3

boto_session = boto3.session.Session()
region = boto_session.region_name

sess = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sess.default_bucket()
prefix = 'keras-fashion-mnist-debugger'

output_path = 's3://{}/{}/output'.format(bucket, prefix)
s3_input_path = 's3://{}/{}/data'.format(bucket, prefix)
training_input_path = s3_input_path + '/train'
validation_input_path = s3_input_path + '/val'

# %% [markdown]
# ## Download the Fashion-MNIST dataset

# %%
import os
import numpy as np
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_val, y_val) = fashion_mnist.load_data()

os.makedirs("./data/train", exist_ok = True)
os.makedirs("./data/val", exist_ok = True)

np.save('./data/train/x_train.npy', x_train)
np.save('./data/train/y_train.npy', y_train)
np.save('./data/val/x_val.npy', x_val)
np.save('./data/val/y_val.npy', y_val)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
# !ls -lat ./data
# Out:
# total 16
# drwxrwxr-x 2 ec2-user ec2-user 4096 Dec 14 15:02 val
# drwxrwxr-x 2 ec2-user ec2-user 4096 Dec 14 15:02 train
# drwxrwxr-x 4 ec2-user ec2-user 4096 Dec 14 15:02 .
# drwxrwxr-x 4 ec2-user ec2-user 4096 Dec 14 15:02 ..

# %% [markdown]
# ##  Upload Fashion-MNIST data to S3

# %%
# !aws s3 sync ./data {s3_input_path}
# Out:
# upload: data/val/y_val.npy to s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/data/val/y_val.npy
# upload: data/train/y_train.npy to s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/data/train/y_train.npy
# upload: data/val/x_val.npy to s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/data/val/x_val.npy
# upload: data/train/x_train.npy to s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/data/train/x_train.npy

# %% [markdown]
# ## Local mode training

# %%
# !pygmentize mnist_keras_tf.py
# Out:
# import argparse, os
# import numpy as np
#
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras import backend as K
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D
# from tensorflow.keras.optimizers import SGD
# from tensorflow.keras.utils import multi_gpu_model
#
# if __name__ == '__main__':
#
#     parser = argparse.ArgumentParser()
#
#     parser.add_argument('--epochs', type=int, default=10)
#     parser.add_argument('--learning-rate', type=float, default=0.01)
#     parser.add_argument('--batch-size', type=int, default=128)
#     parser.add_argument('--gpu-count', type=int, default=os.environ['SM_NUM_GPUS'])
#     parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--training', type=str, default=os.environ['SM_CHANNEL_TRAINING'])
#     parser.add_argument('--validation', type=str, default=os.environ['SM_CHANNEL_VALIDATION'])
#
#     args, _ = parser.parse_known_args()
#
#     epochs     = args.epochs
#     lr         = args.learning_rate
#     batch_size = args.batch_size
#     gpu_count  = args.gpu_count
#     model_dir  = args.model_dir
#     training_dir   = args.training
#     validation_dir = args.validation
#
#     x_train = np.load(os.path.join(training_dir, 'x_train.npy'))
#     y_train = np.load(os.path.join(training_dir, 'y_train.npy'))
#     x_val  = np.load(os.path.join(validation_dir, 'x_val.npy'))
#     y_val  = np.load(os.path.join(validation_dir, 'y_val.npy'))
#
#     # input image dimensions
#     img_rows, img_cols = 28, 28
#
#     print('x_train shape:', x_train.shape)
#     print(x_train.shape[0], 'train samples')
#     print(x_val.shape[0], 'test samples')
#
#     # Normalize pixel values
#     x_train  = x_train.astype('float32')
#     x_val    = x_val.astype('float32')
#     x_train /= 255
#     x_val   /= 255
#
#     # Convert class vectors to binary class matrices
#     num_classes = 10
# #     y_train = keras.utils.to_categorical(y_train, num_classes)
# #     y_val   = keras.utils.to_categorical(y_val, num_classes)
#
# #     model = Sequential()
#
# #     # 1st convolution block
# #     model.add(Conv2D(64, kernel_size=(3,3), padding='same', input_shape=input_shape))
# #     model.add(BatchNormalization(axis=batch_norm_axis))
# #     model.add(Activation('relu'))
# #     model.add(MaxPooling2D(pool_size=(2,2), strides=2))
#
# #     # 2nd convolution block
# #     model.add(Conv2D(128, kernel_size=(3,3), padding='valid'))
# #     model.add(BatchNormalization(axis=batch_norm_axis))
# #     model.add(Activation('relu'))
# #     model.add(MaxPooling2D(pool_size=(2,2), strides=2))
#
# #     # Fully connected block
# #     model.add(Flatten())
# #     model.add(Dense(512))
# #     model.add(Activation('relu'))
# #     model.add(Dropout(0.3))
#
# #     # Output layer
# #     model.add(Dense(num_classes, activation='softmax'))
#
#     model = tf.keras.Sequential([
#         tf.keras.layers.Flatten(input_shape=(28, 28)),
#         tf.keras.layers.Dense(512, activation='relu'),
#         tf.keras.layers.Dense(10, activation='softmax')
#     ])
#
#     print(model.summary())
#
#     if gpu_count > 1:
#         model = multi_gpu_model(model, gpus=gpu_count)
#
# #     model.compile(loss=keras.losses.categorical_crossentropy,
# #                   optimizer=SGD(lr=lr, decay=1e-6, momentum=0.9, nesterov=True),
# #                   metrics=['accuracy', 'mse'])
#
#     model.compile(optimizer='adam',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])
#
#     model.fit(x_train, y_train, batch_size=batch_size,
#                   validation_data=(x_val, y_val),
#                   epochs=epochs,
#                   verbose=1)
#
#     score = model.evaluate(x_val, y_val, verbose=0)
#     print('Validation loss    :', score[0])
#     print('Validation accuracy:', score[1])
#
#     model.save(args.model_dir + '/1')
#
# #     # save Keras model for Tensorflow Serving
# #     sess = K.get_session()
# #     tf.saved_model.simple_save(
# #         sess,
# #         os.path.join(model_dir, 'model/1'),
# #         inputs={'inputs': model.input},
# #         outputs={t.name: t for t in model.outputs})

# %%
from sagemaker.tensorflow import TensorFlow

hyperparams_local={'epochs': 1,
                   'learning-rate': 0.5
                  }

metric_definitions=[
    {'Name': 'train:loss', 'Regex': ' loss: ([0-9\\.]+)'},
    {'Name': 'train:acc', 'Regex': ' accuracy: ([0-9\\.]+)'},
    {'Name': 'val:loss', 'Regex': ' val_loss: ([0-9\\.]+)'},
    {'Name': 'val:acc', 'Regex': ' val_accuracy: ([0-9\\.]+)'}
]

est_local = TensorFlow(entry_point='mnist_keras_tf.py', 
                       role=role,
                       instance_count=1, 
                       instance_type='local',
                       framework_version='2.3', 
                       py_version='py37',
                       output_path=output_path,
                       hyperparameters=hyperparams_local,
                       metric_definitions=metric_definitions
                       )

# %%
est_local.fit({'training': training_input_path, 'validation': validation_input_path})
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: tensorflow-training-2021-12-14-15-02-08-567
# INFO:sagemaker.local.local_session:Starting training job
# INFO:sagemaker.local.image:No AWS credentials found in session but credentials from EC2 Metadata Service are available.
# INFO:sagemaker.local.image:docker compose file:
# networks:
#   sagemaker-local:
#     name: sagemaker-local
# services:
#   algo-1-pefmo:
#     command: train
#     container_name: aock5tgxvl-algo-1-pefmo
#     environment:
#     - '[Masked]'
#     - '[Masked]'
#     image: 763104351884.dkr.ecr.ap-northeast-2.amazonaws.com/tensorflow-training:2.3-cpu-py37
#     networks:
#       sagemaker-local:
#         aliases:
#         - algo-1-pefmo
#     stdin_open: true
#     tty: true
#     volumes:
#     - /tmp/tmpweczgk90/algo-1-pefmo/output:/opt/ml/output
#     - /tmp/tmpweczgk90/algo-1-pefmo/output/data:/opt/ml/output/data
#     - /tmp/tmpweczgk90/algo-1-pefmo/input:/opt/ml/input
#     - /tmp/tmpweczgk90/model:/opt/ml/model
#     - /opt/ml/metadata:/opt/ml/metadata
#     - /tmp/tmps5q24a13:/opt/ml/input/data/training
#     - /tmp/tmpsrjmw9i_:/opt/ml/input/data/validation
# version: '2.3'
#
# INFO:sagemaker.local.image:docker command: docker-compose -f /tmp/tmpweczgk90/docker-compose.yaml up --build --abort-on-container-exit
# INFO:sagemaker.local.image:docker command: docker pull 763104351884.dkr.ecr.ap-northeast-2.amazonaws.com/tensorflow-training:2.3-cpu-py37
# INFO:sagemaker.local.image:image pulled: 763104351884.dkr.ecr.ap-northeast-2.amazonaws.com/tensorflow-training:2.3-cpu-py37
# Creating aock5tgxvl-algo-1-pefmo ...
# Creating aock5tgxvl-algo-1-pefmo ... done
# Attaching to aock5tgxvl-algo-1-pefmo
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:09.190421: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:09.190562: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:09.219903: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:10,449 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:10,458 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:10,652 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:10,673 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:10,687 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:10,697 sagemaker-training-toolkit INFO     Invoking user script
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | Training Env:
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | {
# aock5tgxvl-algo-1-pefmo |     "additional_framework_parameters": {},
# aock5tgxvl-algo-1-pefmo |     "channel_input_dirs": {
# aock5tgxvl-algo-1-pefmo |         "training": "/opt/ml/input/data/training",
# aock5tgxvl-algo-1-pefmo |         "validation": "/opt/ml/input/data/validation"
# aock5tgxvl-algo-1-pefmo |     },
# aock5tgxvl-algo-1-pefmo |     "current_host": "algo-1-pefmo",
# aock5tgxvl-algo-1-pefmo |     "framework_module": "sagemaker_tensorflow_container.training:main",
# aock5tgxvl-algo-1-pefmo |     "hosts": [
# aock5tgxvl-algo-1-pefmo |         "algo-1-pefmo"
# aock5tgxvl-algo-1-pefmo |     ],
# aock5tgxvl-algo-1-pefmo |     "hyperparameters": {
# aock5tgxvl-algo-1-pefmo |         "epochs": 1,
# aock5tgxvl-algo-1-pefmo |         "learning-rate": 0.5,
# aock5tgxvl-algo-1-pefmo |         "model_dir": "s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-training-2021-12-14-15-02-08-567/model"
# aock5tgxvl-algo-1-pefmo |     },
# aock5tgxvl-algo-1-pefmo |     "input_config_dir": "/opt/ml/input/config",
# aock5tgxvl-algo-1-pefmo |     "input_data_config": {
# aock5tgxvl-algo-1-pefmo |         "training": {
# aock5tgxvl-algo-1-pefmo |             "TrainingInputMode": "File"
# aock5tgxvl-algo-1-pefmo |         },
# aock5tgxvl-algo-1-pefmo |         "validation": {
# aock5tgxvl-algo-1-pefmo |             "TrainingInputMode": "File"
# aock5tgxvl-algo-1-pefmo |         }
# aock5tgxvl-algo-1-pefmo |     },
# aock5tgxvl-algo-1-pefmo |     "input_dir": "/opt/ml/input",
# aock5tgxvl-algo-1-pefmo |     "is_master": true,
# aock5tgxvl-algo-1-pefmo |     "job_name": "tensorflow-training-2021-12-14-15-02-08-567",
# aock5tgxvl-algo-1-pefmo |     "log_level": 20,
# aock5tgxvl-algo-1-pefmo |     "master_hostname": "algo-1-pefmo",
# aock5tgxvl-algo-1-pefmo |     "model_dir": "/opt/ml/model",
# aock5tgxvl-algo-1-pefmo |     "module_dir": "s3://sagemaker-ap-northeast-2-889750940888/tensorflow-training-2021-12-14-15-02-08-567/source/sourcedir.tar.gz",
# aock5tgxvl-algo-1-pefmo |     "module_name": "mnist_keras_tf",
# aock5tgxvl-algo-1-pefmo |     "network_interface_name": "eth0",
# aock5tgxvl-algo-1-pefmo |     "num_cpus": 4,
# aock5tgxvl-algo-1-pefmo |     "num_gpus": 0,
# aock5tgxvl-algo-1-pefmo |     "output_data_dir": "/opt/ml/output/data",
# aock5tgxvl-algo-1-pefmo |     "output_dir": "/opt/ml/output",
# aock5tgxvl-algo-1-pefmo |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# aock5tgxvl-algo-1-pefmo |     "resource_config": {
# aock5tgxvl-algo-1-pefmo |         "current_host": "algo-1-pefmo",
# aock5tgxvl-algo-1-pefmo |         "hosts": [
# aock5tgxvl-algo-1-pefmo |             "algo-1-pefmo"
# aock5tgxvl-algo-1-pefmo |         ]
# aock5tgxvl-algo-1-pefmo |     },
# aock5tgxvl-algo-1-pefmo |     "user_entry_point": "mnist_keras_tf.py"
# aock5tgxvl-algo-1-pefmo | }
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | Environment variables:
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | SM_HOSTS=["algo-1-pefmo"]
# aock5tgxvl-algo-1-pefmo | SM_NETWORK_INTERFACE_NAME=eth0
# aock5tgxvl-algo-1-pefmo | SM_HPS={"epochs":1,"learning-rate":0.5,"model_dir":"s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-training-2021-12-14-15-02-08-567/model"}
# aock5tgxvl-algo-1-pefmo | SM_USER_ENTRY_POINT=mnist_keras_tf.py
# aock5tgxvl-algo-1-pefmo | SM_FRAMEWORK_PARAMS={}
# aock5tgxvl-algo-1-pefmo | SM_RESOURCE_CONFIG={"current_host":"algo-1-pefmo","hosts":["algo-1-pefmo"]}
# aock5tgxvl-algo-1-pefmo | SM_INPUT_DATA_CONFIG={"training":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# aock5tgxvl-algo-1-pefmo | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# aock5tgxvl-algo-1-pefmo | SM_CHANNELS=["training","validation"]
# aock5tgxvl-algo-1-pefmo | SM_CURRENT_HOST=algo-1-pefmo
# aock5tgxvl-algo-1-pefmo | SM_MODULE_NAME=mnist_keras_tf
# aock5tgxvl-algo-1-pefmo | SM_LOG_LEVEL=20
# aock5tgxvl-algo-1-pefmo | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# aock5tgxvl-algo-1-pefmo | SM_INPUT_DIR=/opt/ml/input
# aock5tgxvl-algo-1-pefmo | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# aock5tgxvl-algo-1-pefmo | SM_OUTPUT_DIR=/opt/ml/output
# aock5tgxvl-algo-1-pefmo | SM_NUM_CPUS=4
# aock5tgxvl-algo-1-pefmo | SM_NUM_GPUS=0
# aock5tgxvl-algo-1-pefmo | SM_MODEL_DIR=/opt/ml/model
# aock5tgxvl-algo-1-pefmo | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-889750940888/tensorflow-training-2021-12-14-15-02-08-567/source/sourcedir.tar.gz
# aock5tgxvl-algo-1-pefmo | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-pefmo","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-pefmo"],"hyperparameters":{"epochs":1,"learning-rate":0.5,"model_dir":"s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-training-2021-12-14-15-02-08-567/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-12-14-15-02-08-567","log_level":20,"master_hostname":"algo-1-pefmo","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-889750940888/tensorflow-training-2021-12-14-15-02-08-567/source/sourcedir.tar.gz","module_name":"mnist_keras_tf","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-pefmo","hosts":["algo-1-pefmo"]},"user_entry_point":"mnist_keras_tf.py"}
# aock5tgxvl-algo-1-pefmo | SM_USER_ARGS=["--epochs","1","--learning-rate","0.5","--model_dir","s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-training-2021-12-14-15-02-08-567/model"]
# aock5tgxvl-algo-1-pefmo | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# aock5tgxvl-algo-1-pefmo | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# aock5tgxvl-algo-1-pefmo | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# aock5tgxvl-algo-1-pefmo | SM_HP_EPOCHS=1
# aock5tgxvl-algo-1-pefmo | SM_HP_LEARNING-RATE=0.5
# aock5tgxvl-algo-1-pefmo | SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-training-2021-12-14-15-02-08-567/model
# aock5tgxvl-algo-1-pefmo | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | Invoking script with the following command:
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | /usr/local/bin/python3.7 mnist_keras_tf.py --epochs 1 --learning-rate 0.5 --model_dir s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-training-2021-12-14-15-02-08-567/model
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | x_train shape: (60000, 28, 28)
# aock5tgxvl-algo-1-pefmo | 60000 train samples
# aock5tgxvl-algo-1-pefmo | 10000 test samples
# aock5tgxvl-algo-1-pefmo | [2021-12-14 15:03:12.584 db62e58aebc7:29 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# aock5tgxvl-algo-1-pefmo | [2021-12-14 15:03:12.707 db62e58aebc7:29 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# aock5tgxvl-algo-1-pefmo | Model: "sequential"
# aock5tgxvl-algo-1-pefmo | _________________________________________________________________
# aock5tgxvl-algo-1-pefmo | Layer (type)                 Output Shape              Param #
# aock5tgxvl-algo-1-pefmo | =================================================================
# aock5tgxvl-algo-1-pefmo | flatten (Flatten)            (None, 784)               0
# aock5tgxvl-algo-1-pefmo | _________________________________________________________________
# aock5tgxvl-algo-1-pefmo | dense (Dense)                (None, 512)               401920
# aock5tgxvl-algo-1-pefmo | _________________________________________________________________
# aock5tgxvl-algo-1-pefmo | dense_1 (Dense)              (None, 10)                5130
# aock5tgxvl-algo-1-pefmo | =================================================================
# aock5tgxvl-algo-1-pefmo | Total params: 407,050
# aock5tgxvl-algo-1-pefmo | Trainable params: 407,050
# aock5tgxvl-algo-1-pefmo | Non-trainable params: 0
# aock5tgxvl-algo-1-pefmo | _________________________________________________________________
# aock5tgxvl-algo-1-pefmo | None
# 469/469 [==============================] - 2s 4ms/step - loss: 0.5058 - accuracy: 0.8222 - val_loss: 0.4600 - val_accuracy: 0.8402
# aock5tgxvl-algo-1-pefmo | Validation loss    : 0.4599737823009491
# aock5tgxvl-algo-1-pefmo | Validation accuracy: 0.8402000069618225
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:11.021721: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:11.021851: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:11.050701: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# aock5tgxvl-algo-1-pefmo | WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# aock5tgxvl-algo-1-pefmo | Instructions for updating:
# aock5tgxvl-algo-1-pefmo | This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# aock5tgxvl-algo-1-pefmo | WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# aock5tgxvl-algo-1-pefmo | Instructions for updating:
# aock5tgxvl-algo-1-pefmo | This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:15.868113: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# aock5tgxvl-algo-1-pefmo | WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# aock5tgxvl-algo-1-pefmo | Instructions for updating:
# aock5tgxvl-algo-1-pefmo | This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# aock5tgxvl-algo-1-pefmo | WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# aock5tgxvl-algo-1-pefmo | Instructions for updating:
# aock5tgxvl-algo-1-pefmo | This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# aock5tgxvl-algo-1-pefmo | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# aock5tgxvl-algo-1-pefmo | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# aock5tgxvl-algo-1-pefmo |
# aock5tgxvl-algo-1-pefmo | 2021-12-14 15:03:16,408 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# aock5tgxvl-algo-1-pefmo exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## Experiments

# %%
def create_experiment(experiment_name):
    try:
        sm_experiment = Experiment.load(experiment_name)
    except:
        sm_experiment = Experiment.create(experiment_name=experiment_name,
                                          tags=[
                                              {
                                                  'Key': 'modelname',
                                                  'Value': 'fashion-mnist'
                                              },
                                          ])

# %%
def create_trial(experiment_name, i_type, i_cnt, spot):
    create_date = strftime("%m%d-%H%M%s")
    
    algo = 'dp'
    
    spot = 's' if spot else 'd'
    i_tag = 'test'
    
    if i_type == 'ml.p3.16xlarge':
        i_tag = 'p3'
    elif i_type == 'ml.p2.8xlarge':
        i_tag = 'p2'
    elif i_type == 'ml.p3dn.24xlarge':
        i_tag = 'p3dn'
    elif i_type == 'ml.p4d.24xlarge':
        i_tag = 'p4d'
    else:
        i_tag = 'others'
        
    trial = "-".join([i_tag,str(i_cnt),algo, spot])
       
    sm_trial = Trial.create(trial_name=f'{experiment_name}-{trial}-{create_date}',
                            experiment_name=experiment_name)

    job_name = f'{sm_trial.trial_name}'
    return job_name

# %%
experiment_name = 'fashion-mnist-debugger'
# instance_type = 'ml.p3.2xlarge'
instance_type = 'ml.g4dn.4xlarge'
# instance_type = 'ml.c5.2xlarge'
instance_count = 1
do_spot_training=False

create_experiment(experiment_name)
job_name = create_trial(experiment_name, instance_type, instance_count, do_spot_training)
job_name
# Out:
# 'fashion-mnist-debugger-others-1-dp-d-1214-15131639494826'

# %% [markdown]
# ## Debugger
# - https://github.com/aws/amazon-sagemaker-examples/blob/master/sagemaker-debugger/tensorflow2/tensorflow2_zero_code_change/tf2-keras-default-container.ipynb

# %% [markdown]
# ### Hook

# %%
hook_config = DebuggerHookConfig(
    hook_parameters={"save_interval": "100"},
    collection_configs=[
        CollectionConfig("weights"),
        CollectionConfig(name="biases", parameters={"save_interval": "10", "end_step": "500"}),
    ],
)

# %% [markdown]
# ### Rules

# %%
from sagemaker.debugger import Rule, ProfilerRule, rule_configs

rules = [
    Rule.sagemaker(rule_configs.loss_not_decreasing()),
    ProfilerRule.sagemaker(rule_configs.LowGPUUtilization()),
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
]

# %% [markdown]
# ### Profiler

# %%
from sagemaker.debugger import ProfilerConfig, FrameworkProfile

profiler_config = ProfilerConfig(
    system_monitor_interval_millis=500,
    framework_profile_params=FrameworkProfile(
        local_path="/opt/ml/output/profiler/", start_step=5, num_steps=10
    ),
)

# %% [markdown]
# ### Training

# %%
hyperparams_managed={'epochs': 100,
                     'learning-rate': 0.05
                    }

# image_uri = f"763104351884.dkr.ecr.{region}.amazonaws.com/tensorflow-training:2.3.1-gpu-py37-cu110-ubuntu18.04"

# %%
est_managed = TensorFlow(entry_point='mnist_keras_tf.py', 
                         role=role,
                         instance_count=instance_count, 
                         instance_type=instance_type,
                         framework_version='2.3', 
                         py_version='py37',
                         output_path=output_path,
                         hyperparameters=hyperparams_managed,
                         metric_definitions=metric_definitions,
                         base_job_name='tensorflow-debugger',
                         rules=rules,
                         debugger_hook_config=hook_config,
                         disable_profiler=False, # default: False,
                         profiler_config=profiler_config # Debugger Profiling
                         )

# %%
est_managed.fit(inputs={'training': training_input_path, 'validation': validation_input_path},
                experiment_config={
                    'TrialName': job_name,
                    'TrialComponentDisplayName': job_name,
                },
                wait=False)
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: tensorflow-debugger-2021-12-14-15-13-49-481

# %%
job_name=est_managed.latest_training_job.name

# %%
sess.logs_for_job(job_name=job_name, wait=True)
# Out:
# 2021-12-14 15:13:49 Starting - Starting the training job...
# 2021-12-14 15:14:17 Starting - Launching requested ML instancesLossNotDecreasing: InProgress
# LowGPUUtilization: InProgress
# ProfilerReport: InProgress
# ...
# 2021-12-14 15:14:44 Starting - Preparing the instances for training.........
# 2021-12-14 15:16:17 Downloading - Downloading input data
# 2021-12-14 15:16:17 Training - Downloading the training image.........
# 2021-12-14 15:17:50 Training - Training image download completed. Training in progress..2021-12-14 15:17:50.943291: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-12-14 15:17:50.946214: I tensorflow/core/profiler/internal/smprofiler_config_reader.cc:123] PID of the process that is writing to the timeline : 1
# 2021-12-14 15:17:50.946616: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:121] SageMaker Profiler Timeline Writer read the following config parameters :
# 2021-12-14 15:17:50.946626: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:122] Base Folder : /opt/ml/output/profiler/
# 2021-12-14 15:17:50.946630: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:123] Node Id : 1-algo-1
# 2021-12-14 15:17:50.946636: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:124] Maximum file size : 10485760
# 2021-12-14 15:17:50.946640: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:125] Close file interval : 60
# 2021-12-14 15:17:50.946643: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:126] Continuous fail count threshold : 50
# 2021-12-14 15:17:50.946650: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:144] PID of the current Timeline Process : 1
# 2021-12-14 15:17:51.064776: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2021-12-14 15:17:51.121898: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-12-14 15:17:53,264 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-12-14 15:17:53,663 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "learning-rate": 0.05,
#         "model_dir": "s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/model",
#         "epochs": 100
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-debugger-2021-12-14-15-13-49-481",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-889750940888/tensorflow-debugger-2021-12-14-15-13-49-481/source/sourcedir.tar.gz",
#     "module_name": "mnist_keras_tf",
#     "network_interface_name": "eth0",
#     "num_cpus": 16,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist_keras_tf.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":100,"learning-rate":0.05,"model_dir":"s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/model"}
# SM_USER_ENTRY_POINT=mnist_keras_tf.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist_keras_tf
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-889750940888/tensorflow-debugger-2021-12-14-15-13-49-481/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":100,"learning-rate":0.05,"model_dir":"s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-debugger-2021-12-14-15-13-49-481","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-889750940888/tensorflow-debugger-2021-12-14-15-13-49-481/source/sourcedir.tar.gz","module_name":"mnist_keras_tf","network_interface_name":"eth0","num_cpus":16,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist_keras_tf.py"}
# SM_USER_ARGS=["--epochs","100","--learning-rate","0.05","--model_dir","s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_LEARNING-RATE=0.05
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/model
# SM_HP_EPOCHS=100
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 mnist_keras_tf.py --epochs 100 --learning-rate 0.05 --model_dir s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/model
# x_train shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples
# [2021-12-14 15:17:57.956 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-12-14 15:17:58.180 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# None
# [2021-12-14 15:17:58.898 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-12-14 15:17:58.901 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-12-14 15:17:58.903 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2021-12-14 15:17:58.904 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-12-14 15:17:58.909 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO hook.py:425] Monitoring the collections: weights, biases, losses, sm_metrics, metrics
# [2021-12-14 15:17:58.932 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO hook.py:425] Monitoring the collections: weights, biases, losses, sm_metrics, metrics
# Epoch 1/100
# [2021-12-14 15:17:58.969 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/prestepzero-*-start-1639495078180387.2_train-0-stepstart-1639495078969453.0/python_stats.
# #015  1/469 [..............................] - ETA: 0s - loss: 2.3533 - accuracy: 0.1172 - batch: 0.0000e+00[2021-12-14 15:17:59.921 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO keras.py:935] Enabling TF profiler on step: = 5
# [2021-12-14 15:18:00.185 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train-5-stepstart-1639495079919674.5_train-5-stepend-1639495080184711.0/python_stats.
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  6/469 [..............................] - ETA: 21s - loss: 1.6803 - accuracy: 0.4297 - batch: 0.0000e+00[2021-12-14 15:18:00.192 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train-5-stepend-1639495080187339.0_train-6-stepstart-1639495080191939.2/python_stats.
# [2021-12-14 15:18:00.201 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train-6-stepstart-1639495080193469.8_train-6-stepend-1639495080201410.8/python_stats.
# [2021-12-14 15:18:00.206 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train-6-stepend-1639495080203346.0_train-7-stepstart-1639495080206663.8/python_stats.
# [2021-12-14 15:18:00.216 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train-7-stepstart-1639495080207864.5_train-7-stepend-1639495080215659.8/python_stats.
# [2021-12-14 15:18:00.221 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train-7-stepend-1639495080217542.0_train-8-stepstart-1639495080220872.8/python_stats.
# [2021-12-14 15:18:00.230 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train
0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015201/469 [===========>........ ...
# Epoch 99/100
# [2021-12-14 15:19:54.564 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/eval-7741-stepend-1639495194530167.8_train-45962-stepstart-1639495194564714.8/python_stats.
# #015  1/469 [..............................] - ETA: 0s - loss: 0.0787 - accuracy: 0.9844#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 27/469 [>.............................] - ETA: 0s - loss: 0.0242 - accuracy: 0.9916#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 50/469 [==>...........................] - ETA: 0s - loss: 0.0200 - accuracy: 0.9933 - batch: 38.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 76/469 [===>..........................] - ETA: 0s - loss: 0.0212 - accuracy: 0.9927 - batch: 38.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015102/469 [=====>........................] - ETA: 0s - loss: 0.0200 - accuracy: 0.9935 - batch: 38.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015128/469 [=======>......................] - ETA: 0s - loss: 0.0201 - accuracy: 0.9932 - batch: 38.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015150/469 [========>.....................] - ETA: 0s - loss: 0.0207 - accuracy: 0.9927 - batch: 88.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015175/469 [==========>...................] - ETA: 0s - loss: 0.0210 - accuracy: 0.9925 - batch: 88.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015199/469 [===========>..................] - ETA: 0s - loss: 0.0214 - accuracy: 0.9922 - batch:  ...
# Epoch 100/100
# [2021-12-14 15:19:55.721 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/eval-7820-stepend-1639495195688765.8_train-46431-stepstart-1639495195721079.0/python_stats.
# #015  1/469 [..............................] - ETA: 0s - loss: 0.0252 - accuracy: 0.9922#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 27/469 [>.............................] - ETA: 0s - loss: 0.0468 - accuracy: 0.9852#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 48/469 [==>...........................] - ETA: 0s - loss: 0.0431 - accuracy: 0.9852#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 68/469 [===>..........................] - ETA: 0s - loss: 0.0390 - accuracy: 0.9861#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 90/469 [====>.........................] - ETA: 0s - loss: 0.0367 - accuracy: 0.9865 - batch: 69.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015115/469 [======>.......................] - ETA: 0s - loss: 0.0339 - accuracy: 0.9872 - batch: 69.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015140/469 [=======>......................] - ETA: 0s - loss: 0.0311 - accuracy: 0.9883 - batch: 69.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015166/469 [=========>....................] - ETA: 0s - loss: 0.0314 - accuracy: 0.9881 - batch: 69.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015189/469 [===========>..................] - ETA: 0s - loss: 0.0304 - accuracy: 0.9885 - batch: 119.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# [2021-12-14 15:19:56.870 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/eval-7899-stepend-1639495196843982.8_train-46899-stepend-1639495196870412.0/python_stats.
# [2021-12-14 15:19:57.052 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/train-46899-stepend-1639495196873205.0_eval-7900-stepstart-1639495197052268.2/python_stats.
# Validation loss    : 0.7408337593078613
# Validation accuracy: 0.8942000269889832
# [2021-12-14 15:20:03.757 ip-10-0-88-114.ap-northeast-2.compute.internal:52 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/52-algo-1/eval-8212-stepend-1639495197573745.2_posthookclose-*-end-1639495203755498.0/python_stats.
# 2021-12-14 15:17:53.966983: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-12-14 15:17:54.002841: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2021-12-14 15:19:58.750351: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 2021-12-14 15:20:04,366 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-12-14 15:20:19 Uploading - Uploading generated training model
# 2021-12-14 15:20:19 Completed - Training job completed
# Training seconds: 267
# Billable seconds: 267

# %% [markdown]
# ### Download profiler report

# %%
profiler_path = './profiler-{}'.format(strftime("%m%d-%H%M%s"))

# %%
os.makedirs(profiler_path, exist_ok=True)

# %%
rule_output_path = est_managed.output_path + '/' + est_managed.latest_training_job.job_name + "/rule-output"
rule_output_path
# Out:
# 's3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output'

# %%
! aws s3 cp {rule_output_path} {profiler_path} --recursive
# Out:
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/CPUBottleneck.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/CPUBottleneck.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-report.ipynb to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-report.ipynb
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/Dataloader.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/Dataloader.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-report.html to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-report.html
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/StepOutlier.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/StepOutlier.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/IOBottleneck.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/IOBottleneck.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/LoadBalancing.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/LoadBalancing.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/OverallFrameworkMetrics.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/LowGPUUtilization.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/LowGPUUtilization.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/OverallSystemUsage.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/OverallSystemUsage.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/MaxInitializationTime.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/MaxInitializationTime.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/GPUMemoryIncrease.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/GPUMemoryIncrease.json
# download: s3://sagemaker-ap-northeast-2-889750940888/keras-fashion-mnist-debugger/output/tensorflow-debugger-2021-12-14-15-13-49-481/rule-output/ProfilerReport/profiler-output/profiler-reports/BatchSize.json to profiler-1214-15201639495233/ProfilerReport/profiler-output/profiler-reports/BatchSize.json
