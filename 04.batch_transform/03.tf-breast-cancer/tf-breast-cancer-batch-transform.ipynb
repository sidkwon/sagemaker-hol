# %% [markdown]
# # Amazon SageMaker Batch Transform
# https://github.com/aws/amazon-sagemaker-examples/blob/master/sagemaker_batch_transform/batch_transform_associate_predictions_with_input/Batch%20Transform%20-%20breast%20cancer%20prediction%20with%20high%20level%20SDK.ipynb

# %% [markdown]
# ## Setup
#
# Let's start by specifying:
#
# * The SageMaker role arn used to give training and batch transform access to your data. The snippet below will use the same role used by your SageMaker notebook instance. Otherwise, specify the full ARN of a role with the SageMakerFullAccess policy attached.
# * The S3 bucket that you want to use for training and storing model objects.

# %%
import os
import boto3
import sagemaker

role = sagemaker.get_execution_role()
sess = sagemaker.Session()

bucket = sess.default_bucket()
prefix = "DEMO-breast-cancer-prediction-tf-batch-transform"

# %% [markdown]
# ---
# ## Data sources
#
# > https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
# > https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
#
# ## Attributes
# 1) ID number
# 2) Diagnosis (M = malignant(악성종양), B = benign(양성종양))
# 3-32)
#
# Ten real-valued features are computed for each cell nucleus: (_mean: mean / _se: standard deviation / _worst: worst)
#
# a) radius (mean of distances from center to points on the perimeter)
# b) texture (standard deviation of gray-scale values)
# c) perimeter
# d) area
# e) smoothness (local variation in radius lengths)
# f) compactness (perimeter^2 / area - 1.0)
# g) concavity (severity of concave portions of the contour)
# h) concave points (number of concave portions of the contour)
# i) symmetry
# j) fractal dimension ("coastline approximation" - 1)
#
# ## Data preparation
#
#
# Let's download the data and save it in the local folder with the name data.csv and take a look at it.

# %%
import pandas as pd
import numpy as np

s3 = boto3.client("s3")

filename = "wdbc.csv"
s3.download_file("sagemaker-sample-files", "datasets/tabular/breast_cancer/wdbc.csv", filename)
data = pd.read_csv(filename, header=None)

# specify columns extracted from wbdc.names
data.columns = [
    "id",
    "diagnosis",
    "radius_mean",
    "texture_mean",
    "perimeter_mean",
    "area_mean",
    "smoothness_mean",
    "compactness_mean",
    "concavity_mean",
    "concave points_mean",
    "symmetry_mean",
    "fractal_dimension_mean",
    "radius_se",
    "texture_se",
    "perimeter_se",
    "area_se",
    "smoothness_se",
    "compactness_se",
    "concavity_se",
    "concave points_se",
    "symmetry_se",
    "fractal_dimension_se",
    "radius_worst",
    "texture_worst",
    "perimeter_worst",
    "area_worst",
    "smoothness_worst",
    "compactness_worst",
    "concavity_worst",
    "concave points_worst",
    "symmetry_worst",
    "fractal_dimension_worst",
]

# save the data
data.to_csv("data.csv", sep=",", index=False)

data.head(8)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# 2          0.10960           0.15990         0.19740              0.12790
# 3          0.14250           0.28390         0.24140              0.10520
# 4          0.10030           0.13280         0.19800              0.10430
# 5          0.12780           0.17000         0.15780              0.08089
# 6          0.09463           0.10900         0.11270              0.07400
# 7          0.11890           0.16450         0.09366              0.05985
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
# 5  ...         15.47          23.75           103.40       741.6
# 6  ...         22.88          27.66           153.20      1606.0
# 7  ...         17.06          28.14           110.60       897.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
# 6            0.1442             0.2576           0.3784                0.1932
# 7            0.1654             0.3682           0.2678                0.1556
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
# 5          0.3985                  0.12440
# 6          0.3063                  0.08368
# 7          0.3196                  0.11510
#
# [8 rows x 32 columns]

# %% [markdown]
# #### Key observations:
# * The data has 569 observations and 32 columns.
# * **The first field is the 'id' attribute that we will want to drop before batch inference and add to the final inference output next to the probability of malignancy.**
# * Second field, 'diagnosis', is an indicator of the actual diagnosis ('M' = Malignant; 'B' = Benign).
# * There are 30 other numeric features that we will use for training and inferencing.

# %% [markdown]
# Let's replace the M/B diagnosis with a 1/0 boolean value.

# %%
data["diagnosis"] = data["diagnosis"].apply(lambda x: 0 if x == "M" else 1)
data.head(8)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          0        17.99         10.38          122.80     1001.0
# 1    842517          0        20.57         17.77          132.90     1326.0
# 2  84300903          0        19.69         21.25          130.00     1203.0
# 3  84348301          0        11.42         20.38           77.58      386.1
# 4  84358402          0        20.29         14.34          135.10     1297.0
# 5    843786          0        12.45         15.70           82.57      477.1
# 6    844359          0        18.25         19.98          119.60     1040.0
# 7  84458202          0        13.71         20.83           90.20      577.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# 2          0.10960           0.15990         0.19740              0.12790
# 3          0.14250           0.28390         0.24140              0.10520
# 4          0.10030           0.13280         0.19800              0.10430
# 5          0.12780           0.17000         0.15780              0.08089
# 6          0.09463           0.10900         0.11270              0.07400
# 7          0.11890           0.16450         0.09366              0.05985
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
# 5  ...         15.47          23.75           103.40       741.6
# 6  ...         22.88          27.66           153.20      1606.0
# 7  ...         17.06          28.14           110.60       897.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
# 6            0.1442             0.2576           0.3784                0.1932
# 7            0.1654             0.3682           0.2678                0.1556
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
# 5          0.3985                  0.12440
# 6          0.3063                  0.08368
# 7          0.3196                  0.11510
#
# [8 rows x 32 columns]

# %% [markdown]
# Let's split the data as follows: 80% for training, 10% for validation and let's set 10% aside for our batch inference job. In addition, let's drop the 'id' field on the training set and validation set as 'id' is not a training feature. For our batch set however, we keep the 'id' feature. We'll want to filter it out prior to running our inferences so that the input data features match the ones of training set and then ultimately, we'll want to join it with inference result. We are however dropping the diagnosis attribute for the batch set since this is what we'll try to predict.

# %%
# data split in three sets, training, validation and batch inference
rand_split = np.random.rand(len(data))
train_list = rand_split < 0.8
val_list = (rand_split >= 0.8) & (rand_split < 0.9)
batch_list = rand_split >= 0.9

data_train = data[train_list].drop(["id"], axis=1)
data_train_x = data_train.drop(["diagnosis"], axis=1)
data_train_y = data_train["diagnosis"]

data_val = data[val_list].drop(["id"], axis=1)
data_val_x = data_val.drop(["diagnosis"], axis=1)
data_val_y = data_val["diagnosis"]

# data_batch = data[batch_list].drop(["diagnosis"], axis=1)
data_batch = data[batch_list]

# %%
train_dir = os.path.join(os.getcwd(), 'data/train')
os.makedirs(train_dir, exist_ok=True)

val_dir = os.path.join(os.getcwd(), 'data/val')
os.makedirs(val_dir, exist_ok=True)

batch_dir = os.path.join(os.getcwd(), 'data/batch')
os.makedirs(batch_dir, exist_ok=True)

# %%
np.save(os.path.join(train_dir, 'data_train_x.npy'), data_train_x.to_numpy())
np.save(os.path.join(train_dir, 'data_train_y.npy'), data_train_y.to_numpy())

np.save(os.path.join(val_dir, 'data_val_x.npy'), data_val_x.to_numpy())
np.save(os.path.join(val_dir, 'data_val_y.npy'), data_val_y.to_numpy())

# np.save(os.path.join(batch_dir, 'data_batch.npy'), data_train_x.to_numpy())
# np.save(os.path.join(batch_dir, 'data_batch_noID.npy'), data_train_y.to_numpy())

data_batch.to_csv(os.path.join(batch_dir, 'data_batch.csv'), sep=',', index=False, header=False)

# %% [markdown]
# Let's upload those data sets in S3

# %%
# !aws s3 sync ./data s3://{bucket}/{prefix}/data
# Out:
# upload: data/batch/data_batch.csv to s3://sagemaker-ap-northeast-2-889750940888/DEMO-breast-cancer-prediction-tf-batch-transform/data/batch/data_batch.csv
# upload: data/train/data_train_y.npy to s3://sagemaker-ap-northeast-2-889750940888/DEMO-breast-cancer-prediction-tf-batch-transform/data/train/data_train_y.npy
# upload: data/train/data_train_x.npy to s3://sagemaker-ap-northeast-2-889750940888/DEMO-breast-cancer-prediction-tf-batch-transform/data/train/data_train_x.npy
# upload: data/val/data_val_y.npy to s3://sagemaker-ap-northeast-2-889750940888/DEMO-breast-cancer-prediction-tf-batch-transform/data/val/data_val_y.npy
# upload: data/val/data_val_x.npy to s3://sagemaker-ap-northeast-2-889750940888/DEMO-breast-cancer-prediction-tf-batch-transform/data/val/data_val_x.npy

# %% [markdown]
# Verify if S3 upload has been completed as expected

# %%
# !aws s3 ls s3://{bucket}/{prefix}/data --recursive
# Out:
# 2022-01-05 03:53:12      11840 DEMO-breast-cancer-prediction-tf-batch-transform/data/batch/.ipynb_checkpoints/data_batch-checkpoint.csv
# 2022-01-04 13:15:31      11431 DEMO-breast-cancer-prediction-tf-batch-transform/data/batch/.ipynb_checkpoints/data_batch_noID-checkpoint.csv
# 2022-01-05 08:44:17      14338 DEMO-breast-cancer-prediction-tf-batch-transform/data/batch/data_batch.csv
# 2022-01-05 04:23:34      11543 DEMO-breast-cancer-prediction-tf-batch-transform/data/batch/data_batch_noID.csv
# 2022-01-05 04:58:10      21098 DEMO-breast-cancer-prediction-tf-batch-transform/data/batch/data_batch_single.csv
# 2022-01-05 08:44:17     108368 DEMO-breast-cancer-prediction-tf-batch-transform/data/train/data_train_x.npy
# 2022-01-05 08:44:17       3736 DEMO-breast-cancer-prediction-tf-batch-transform/data/train/data_train_y.npy
# 2022-01-05 08:44:17      12848 DEMO-breast-cancer-prediction-tf-batch-transform/data/val/data_val_x.npy
# 2022-01-05 08:44:17        552 DEMO-breast-cancer-prediction-tf-batch-transform/data/val/data_val_y.npy

# %% [markdown]
# ---
#
# ## Training job and model creation

# %%
# %%writefile source_dir/tf_batch.py
import argparse
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

def parse_args():
    
    parser = argparse.ArgumentParser()

    # 사용자가 전달한 하이퍼 파라미터를 command-line argument로 전달받아 사용함
    parser.add_argument('--epochs', type=int, default=1)
    parser.add_argument('--batch_size', type=int, default=64)
    parser.add_argument('--learning_rate', type=float, default=0.1)
    
    # data directories
    parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAIN'))
    parser.add_argument('--validation', type=str, default=os.environ.get('SM_CHANNEL_VALIDATION'))
    
    # model directory: we will use the default set by SageMaker, /opt/ml/model
    parser.add_argument('--model_dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
    
    return parser.parse_known_args()

    
def get_train_data(train_dir):
    
    x_train = np.load(os.path.join(train_dir, 'data_train_x.npy'), allow_pickle=True)
    y_train = np.load(os.path.join(train_dir, 'data_train_y.npy'), allow_pickle=True)
    print('x_train', x_train.shape,'y_train', y_train.shape)

    return x_train, y_train


def get_validation_data(validation_dir):
    
    x_validation = np.load(os.path.join(validation_dir, 'data_val_x.npy'), allow_pickle=True)
    y_validation = np.load(os.path.join(validation_dir, 'data_val_y.npy'), allow_pickle=True)
    print('x_validation', x_validation.shape,'y_validation', y_validation.shape)

    return x_validation, y_validation

if __name__ == "__main__":
    args, _ = parse_args()
    
    x_train, y_train = get_train_data(args.train)
    x_validation, y_validation = get_validation_data(args.validation)
    
    device = '/cpu:0' 
    print(device)
    batch_size = args.batch_size
    epochs = args.epochs
    learning_rate = args.learning_rate
    print('batch_size = {}, epochs = {}, learning rate = {}'.format(batch_size, epochs, learning_rate))

    with tf.device(device):
        model = tf.keras.Sequential([
                # input layer
                tf.keras.layers.Dense(30, input_shape=(30,), activation='relu'),
                tf.keras.layers.Dense(15, activation='relu'),
                tf.keras.layers.Dense(10,activation = 'relu'),
                # we use sigmoid for binary output
                # output layer
                tf.keras.layers.Dense(1, activation='sigmoid')
            ]
        )

        model.summary()
        
        model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'mse'])    
        model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                  validation_data=(x_validation, y_validation))

        # evaluate on test set
        scores = model.evaluate(x_validation, y_validation, batch_size, verbose=2)
        print("\nTest MSE :", scores)
        
        model.save(args.model_dir + '/1')
# Out:
# Overwriting source_dir/tf_batch.py

# %% [markdown]
# ### Local mode training

# %%
from sagemaker.tensorflow import TensorFlow

model_dir = '/opt/ml/model'
instance_type = 'local'
hyperparameters = {'epochs': 5, 'batch_size': 10, 'learning_rate': 0.001}

local_estimator = TensorFlow(source_dir='source_dir',
                             entry_point='tf_batch.py',
                             model_dir=model_dir,
                             instance_type=instance_type,
                             instance_count=1,
                             hyperparameters=hyperparameters,
                             role=sagemaker.get_execution_role(),
                             base_job_name='tf-batch-transform',
                             framework_version='2.1',
                             py_version='py3')

# %%
inputs = {'train': f'file://{train_dir}',
          'validation': f'file://{val_dir}'}

local_estimator.fit(inputs)
# Out:
# Creating 1hrql697ak-algo-1-e1mdu ...
# Creating 1hrql697ak-algo-1-e1mdu ... done
# Attaching to 1hrql697ak-algo-1-e1mdu
# 1hrql697ak-algo-1-e1mdu | 2022-01-05 08:44:20,920 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 1hrql697ak-algo-1-e1mdu | 2022-01-05 08:44:20,926 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 1hrql697ak-algo-1-e1mdu | 2022-01-05 08:44:21,074 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 1hrql697ak-algo-1-e1mdu | 2022-01-05 08:44:21,089 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 1hrql697ak-algo-1-e1mdu | 2022-01-05 08:44:21,104 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 1hrql697ak-algo-1-e1mdu | 2022-01-05 08:44:21,115 sagemaker-training-toolkit INFO     Invoking user script
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | Training Env:
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | {
# 1hrql697ak-algo-1-e1mdu |     "additional_framework_parameters": {},
# 1hrql697ak-algo-1-e1mdu |     "channel_input_dirs": {
# 1hrql697ak-algo-1-e1mdu |         "train": "/opt/ml/input/data/train",
# 1hrql697ak-algo-1-e1mdu |         "validation": "/opt/ml/input/data/validation"
# 1hrql697ak-algo-1-e1mdu |     },
# 1hrql697ak-algo-1-e1mdu |     "current_host": "algo-1-e1mdu",
# 1hrql697ak-algo-1-e1mdu |     "framework_module": "sagemaker_tensorflow_container.training:main",
# 1hrql697ak-algo-1-e1mdu |     "hosts": [
# 1hrql697ak-algo-1-e1mdu |         "algo-1-e1mdu"
# 1hrql697ak-algo-1-e1mdu |     ],
# 1hrql697ak-algo-1-e1mdu |     "hyperparameters": {
# 1hrql697ak-algo-1-e1mdu |         "epochs": 5,
# 1hrql697ak-algo-1-e1mdu |         "batch_size": 10,
# 1hrql697ak-algo-1-e1mdu |         "learning_rate": 0.001,
# 1hrql697ak-algo-1-e1mdu |         "model_dir": "/opt/ml/model"
# 1hrql697ak-algo-1-e1mdu |     },
# 1hrql697ak-algo-1-e1mdu |     "input_config_dir": "/opt/ml/input/config",
# 1hrql697ak-algo-1-e1mdu |     "input_data_config": {
# 1hrql697ak-algo-1-e1mdu |         "train": {
# 1hrql697ak-algo-1-e1mdu |             "TrainingInputMode": "File"
# 1hrql697ak-algo-1-e1mdu |         },
# 1hrql697ak-algo-1-e1mdu |         "validation": {
# 1hrql697ak-algo-1-e1mdu |             "TrainingInputMode": "File"
# 1hrql697ak-algo-1-e1mdu |         }
# 1hrql697ak-algo-1-e1mdu |     },
# 1hrql697ak-algo-1-e1mdu |     "input_dir": "/opt/ml/input",
# 1hrql697ak-algo-1-e1mdu |     "is_master": true,
# 1hrql697ak-algo-1-e1mdu |     "job_name": "tf-batch-transform-2022-01-05-08-44-17-269",
# 1hrql697ak-algo-1-e1mdu |     "log_level": 20,
# 1hrql697ak-algo-1-e1mdu |     "master_hostname": "algo-1-e1mdu",
# 1hrql697ak-algo-1-e1mdu |     "model_dir": "/opt/ml/model",
# 1hrql697ak-algo-1-e1mdu |     "module_dir": "s3://sagemaker-ap-northeast-2-889750940888/tf-batch-transform-2022-01-05-08-44-17-269/source/sourcedir.tar.gz",
# 1hrql697ak-algo-1-e1mdu |     "module_name": "tf_batch",
# 1hrql697ak-algo-1-e1mdu |     "network_interface_name": "eth0",
# 1hrql697ak-algo-1-e1mdu |     "num_cpus": 4,
# 1hrql697ak-algo-1-e1mdu |     "num_gpus": 0,
# 1hrql697ak-algo-1-e1mdu |     "output_data_dir": "/opt/ml/output/data",
# 1hrql697ak-algo-1-e1mdu |     "output_dir": "/opt/ml/output",
# 1hrql697ak-algo-1-e1mdu |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 1hrql697ak-algo-1-e1mdu |     "resource_config": {
# 1hrql697ak-algo-1-e1mdu |         "current_host": "algo-1-e1mdu",
# 1hrql697ak-algo-1-e1mdu |         "hosts": [
# 1hrql697ak-algo-1-e1mdu |             "algo-1-e1mdu"
# 1hrql697ak-algo-1-e1mdu |         ]
# 1hrql697ak-algo-1-e1mdu |     },
# 1hrql697ak-algo-1-e1mdu |     "user_entry_point": "tf_batch.py"
# 1hrql697ak-algo-1-e1mdu | }
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | Environment variables:
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | SM_HOSTS=["algo-1-e1mdu"]
# 1hrql697ak-algo-1-e1mdu | SM_NETWORK_INTERFACE_NAME=eth0
# 1hrql697ak-algo-1-e1mdu | SM_HPS={"batch_size":10,"epochs":5,"learning_rate":0.001,"model_dir":"/opt/ml/model"}
# 1hrql697ak-algo-1-e1mdu | SM_USER_ENTRY_POINT=tf_batch.py
# 1hrql697ak-algo-1-e1mdu | SM_FRAMEWORK_PARAMS={}
# 1hrql697ak-algo-1-e1mdu | SM_RESOURCE_CONFIG={"current_host":"algo-1-e1mdu","hosts":["algo-1-e1mdu"]}
# 1hrql697ak-algo-1-e1mdu | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# 1hrql697ak-algo-1-e1mdu | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 1hrql697ak-algo-1-e1mdu | SM_CHANNELS=["train","validation"]
# 1hrql697ak-algo-1-e1mdu | SM_CURRENT_HOST=algo-1-e1mdu
# 1hrql697ak-algo-1-e1mdu | SM_MODULE_NAME=tf_batch
# 1hrql697ak-algo-1-e1mdu | SM_LOG_LEVEL=20
# 1hrql697ak-algo-1-e1mdu | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# 1hrql697ak-algo-1-e1mdu | SM_INPUT_DIR=/opt/ml/input
# 1hrql697ak-algo-1-e1mdu | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 1hrql697ak-algo-1-e1mdu | SM_OUTPUT_DIR=/opt/ml/output
# 1hrql697ak-algo-1-e1mdu | SM_NUM_CPUS=4
# 1hrql697ak-algo-1-e1mdu | SM_NUM_GPUS=0
# 1hrql697ak-algo-1-e1mdu | SM_MODEL_DIR=/opt/ml/model
# 1hrql697ak-algo-1-e1mdu | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-889750940888/tf-batch-transform-2022-01-05-08-44-17-269/source/sourcedir.tar.gz
# 1hrql697ak-algo-1-e1mdu | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-e1mdu","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-e1mdu"],"hyperparameters":{"batch_size":10,"epochs":5,"learning_rate":0.001,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tf-batch-transform-2022-01-05-08-44-17-269","log_level":20,"master_hostname":"algo-1-e1mdu","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-889750940888/tf-batch-transform-2022-01-05-08-44-17-269/source/sourcedir.tar.gz","module_name":"tf_batch","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-e1mdu","hosts":["algo-1-e1mdu"]},"user_entry_point":"tf_batch.py"}
# 1hrql697ak-algo-1-e1mdu | SM_USER_ARGS=["--batch_size","10","--epochs","5","--learning_rate","0.001","--model_dir","/opt/ml/model"]
# 1hrql697ak-algo-1-e1mdu | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 1hrql697ak-algo-1-e1mdu | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# 1hrql697ak-algo-1-e1mdu | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# 1hrql697ak-algo-1-e1mdu | SM_HP_EPOCHS=5
# 1hrql697ak-algo-1-e1mdu | SM_HP_BATCH_SIZE=10
# 1hrql697ak-algo-1-e1mdu | SM_HP_LEARNING_RATE=0.001
# 1hrql697ak-algo-1-e1mdu | SM_HP_MODEL_DIR=/opt/ml/model
# 1hrql697ak-algo-1-e1mdu | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | Invoking script with the following command:
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | /usr/local/bin/python3.6 tf_batch.py --batch_size 10 --epochs 5 --learning_rate 0.001 --model_dir /opt/ml/model
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | x_train (451, 30) y_train (451,)
# 1hrql697ak-algo-1-e1mdu | x_validation (53, 30) y_validation (53,)
# 1hrql697ak-algo-1-e1mdu | /cpu:0
# 1hrql697ak-algo-1-e1mdu | batch_size = 10, epochs = 5, learning rate = 0.001
# 1hrql697ak-algo-1-e1mdu | Model: "sequential"
# 1hrql697ak-algo-1-e1mdu | _________________________________________________________________
# 1hrql697ak-algo-1-e1mdu | Layer (type)                 Output Shape              Param #
# 1hrql697ak-algo-1-e1mdu | =================================================================
# 1hrql697ak-algo-1-e1mdu | dense (Dense)                (None, 30)                930
# 1hrql697ak-algo-1-e1mdu | _________________________________________________________________
# 1hrql697ak-algo-1-e1mdu | dense_1 (Dense)              (None, 15)                465
# 1hrql697ak-algo-1-e1mdu | _________________________________________________________________
# 1hrql697ak-algo-1-e1mdu | dense_2 (Dense)              (None, 10)                160
# 1hrql697ak-algo-1-e1mdu | _________________________________________________________________
# 1hrql697ak-algo-1-e1mdu | dense_3 (Dense)              (None, 1)                 11
# 1hrql697ak-algo-1-e1mdu | =================================================================
# 1hrql697ak-algo-1-e1mdu | Total params: 1,566
# 1hrql697ak-algo-1-e1mdu | Trainable params: 1,566
# 1hrql697ak-algo-1-e1mdu | Non-trainable params: 0
# 1hrql697ak-algo-1-e1mdu | _________________________________________________________________
# 1hrql697ak-algo-1-e1mdu | Train on 451 samples, validate on 53 samples
# 1hrql697ak-algo-1-e1mdu | Epoch 1/5
# 451/451 [==============================] - 1s 2ms/sample - loss: 10.9217 - accuracy: 0.6608 - mse: 0.3229 - val_loss: 0.4778 - val_accuracy: 0.9245 - val_mse: 0.0740
# 1hrql697ak-algo-1-e1mdu | Epoch 2/5
# 451/451 [==============================] - 0s 341us/sample - loss: 0.4511 - accuracy: 0.8426 - mse: 0.1175 - val_loss: 0.3278 - val_accuracy: 0.8868 - val_mse: 0.0821
# 1hrql697ak-algo-1-e1mdu | Epoch 3/5
# 451/451 [==============================] - 0s 430us/sample - loss: 0.2638 - accuracy: 0.9047 - mse: 0.0744 - val_loss: 0.5256 - val_accuracy: 0.7925 - val_mse: 0.1624
# 1hrql697ak-algo-1-e1mdu | Epoch 4/5
# 451/451 [==============================] - 0s 353us/sample - loss: 0.2846 - accuracy: 0.9024 - mse: 0.0786 - val_loss: 0.3355 - val_accuracy: 0.9057 - val_mse: 0.0783
# 1hrql697ak-algo-1-e1mdu | Epoch 5/5
# 451/451 [==============================] - 0s 445us/sample - loss: 0.3157 - accuracy: 0.8869 - mse: 0.0872 - val_loss: 0.2924 - val_accuracy: 0.9057 - val_mse: 0.0788
# 1hrql697ak-algo-1-e1mdu | 53/53 - 0s - loss: 0.2924 - accuracy: 0.9057 - mse: 0.0788
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | Test MSE : [0.2923622101826488, 0.9056604, 0.0787742]
# 1hrql697ak-algo-1-e1mdu | WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# 1hrql697ak-algo-1-e1mdu | Instructions for updating:
# 1hrql697ak-algo-1-e1mdu | If using Keras pass *_constraint arguments to layers.
# 1hrql697ak-algo-1-e1mdu | WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# 1hrql697ak-algo-1-e1mdu | Instructions for updating:
# 1hrql697ak-algo-1-e1mdu | If using Keras pass *_constraint arguments to layers.
# 1hrql697ak-algo-1-e1mdu | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 1hrql697ak-algo-1-e1mdu | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 1hrql697ak-algo-1-e1mdu |
# 1hrql697ak-algo-1-e1mdu | 2022-01-05 08:44:25,687 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 1hrql697ak-algo-1-e1mdu exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %%
local_predictor = local_estimator.deploy(instance_type='local', initial_instance_count=1)
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Attaching to gsm9go1o63-algo-1-dswgh
# gsm9go1o63-algo-1-dswgh | INFO:__main__:starting services
# gsm9go1o63-algo-1-dswgh | INFO:tfs_utils:using default model name: model
# gsm9go1o63-algo-1-dswgh | INFO:tfs_utils:tensorflow serving model config:
# gsm9go1o63-algo-1-dswgh | model_config_list: {
# gsm9go1o63-algo-1-dswgh |   config: {
# gsm9go1o63-algo-1-dswgh |     name: "model",
# gsm9go1o63-algo-1-dswgh |     base_path: "/opt/ml/model",
# gsm9go1o63-algo-1-dswgh |     model_platform: "tensorflow"
# gsm9go1o63-algo-1-dswgh |   }
# gsm9go1o63-algo-1-dswgh | }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh | INFO:__main__:using default model name: model
# gsm9go1o63-algo-1-dswgh | INFO:__main__:tensorflow serving model config:
# gsm9go1o63-algo-1-dswgh | model_config_list: {
# gsm9go1o63-algo-1-dswgh |   config: {
# gsm9go1o63-algo-1-dswgh |     name: "model",
# gsm9go1o63-algo-1-dswgh |     base_path: "/opt/ml/model",
# gsm9go1o63-algo-1-dswgh |     model_platform: "tensorflow"
# gsm9go1o63-algo-1-dswgh |   }
# gsm9go1o63-algo-1-dswgh | }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh | INFO:__main__:tensorflow version info:
# gsm9go1o63-algo-1-dswgh | TensorFlow ModelServer: 2.1.0-rc1+dev.sha.d80de10
# gsm9go1o63-algo-1-dswgh | TensorFlow Library: 2.1.1
# gsm9go1o63-algo-1-dswgh | INFO:__main__:tensorflow serving command: tensorflow_model_server --port=9000 --rest_api_port=8501 --model_config_file=/sagemaker/model-config.cfg --max_num_load_retries=0
# gsm9go1o63-algo-1-dswgh | INFO:__main__:started tensorflow serving (pid: 12)
# gsm9go1o63-algo-1-dswgh | INFO:__main__:nginx config:
# gsm9go1o63-algo-1-dswgh | load_module modules/ngx_http_js_module.so;
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh | worker_processes auto;
# gsm9go1o63-algo-1-dswgh | daemon off;
# gsm9go1o63-algo-1-dswgh | pid /tmp/nginx.pid;
# gsm9go1o63-algo-1-dswgh | error_log  /dev/stderr info;
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh | worker_rlimit_nofile 4096;
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh | events {
# gsm9go1o63-algo-1-dswgh |   worker_connections 2048;
# gsm9go1o63-algo-1-dswgh | }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh | http {
# gsm9go1o63-algo-1-dswgh |   include /etc/nginx/mime.types;
# gsm9go1o63-algo-1-dswgh |   default_type application/json;
# gsm9go1o63-algo-1-dswgh |   access_log /dev/stdout combined;
# gsm9go1o63-algo-1-dswgh |   js_include tensorflow-serving.js;
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |   upstream tfs_upstream {
# gsm9go1o63-algo-1-dswgh |     server localhost:8501;
# gsm9go1o63-algo-1-dswgh |   }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |   upstream gunicorn_upstream {
# gsm9go1o63-algo-1-dswgh |     server unix:/tmp/gunicorn.sock fail_timeout=1;
# gsm9go1o63-algo-1-dswgh |   }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |   server {
# gsm9go1o63-algo-1-dswgh |     listen 8080 deferred;
# gsm9go1o63-algo-1-dswgh |     client_max_body_size 0;
# gsm9go1o63-algo-1-dswgh |     client_body_buffer_size 100m;
# gsm9go1o63-algo-1-dswgh |     subrequest_output_buffer_size 100m;
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |     set $tfs_version 2.1;
# gsm9go1o63-algo-1-dswgh |     set $default_tfs_model model;
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |     location /tfs {
# gsm9go1o63-algo-1-dswgh |         rewrite ^/tfs/(.*) /$1  break;
# gsm9go1o63-algo-1-dswgh |         proxy_redirect off;
# gsm9go1o63-algo-1-dswgh |         proxy_pass_request_headers off;
# gsm9go1o63-algo-1-dswgh |         proxy_set_header Content-Type 'application/json';
# gsm9go1o63-algo-1-dswgh |         proxy_set_header Accept 'application/json';
# gsm9go1o63-algo-1-dswgh |         proxy_pass http://tfs_upstream;
# gsm9go1o63-algo-1-dswgh |     }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |     location /ping {
# gsm9go1o63-algo-1-dswgh |         js_content ping;
# gsm9go1o63-algo-1-dswgh |     }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |     location /invocations {
# gsm9go1o63-algo-1-dswgh |         js_content invocations;
# gsm9go1o63-algo-1-dswgh |     }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |     location /models {
# gsm9go1o63-algo-1-dswgh |         proxy_pass http://gunicorn_upstream/models;
# gsm9go1o63-algo-1-dswgh |     }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |     location / {
# gsm9go1o63-algo-1-dswgh |         return 404 '{"error": "Not Found"}';
# gsm9go1o63-algo-1-dswgh |     }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |     keepalive_timeout 3;
# gsm9go1o63-algo-1-dswgh |   }
# gsm9go1o63-algo-1-dswgh | }
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh |
# gsm9go1o63-algo-1-dswgh | INFO:__main__:nginx version info:
# gsm9go1o63-algo-1-dswgh | nginx version: nginx/1.18.0
# gsm9go1o63-algo-1-dswgh | built by gcc 7.5.0 (Ubuntu 7.5.0-3ubuntu1~18.04)
# gsm9go1o63-algo-1-dswgh | built with OpenSSL 1.1.1  11 Sep 2018
# gsm9go1o63-algo-1-dswgh | TLS SNI support enabled
# gsm9go1o63-algo-1-dswgh | configure arguments: --prefix=/etc/nginx --sbin-path=/usr/sbin/nginx --modules-path=/usr/lib/nginx/modules --conf-path=/etc/nginx/nginx.conf --error-log-path=/var/log/nginx/error.log --http-log-path=/var/log/nginx/access.log --pid-path=/var/run/nginx.pid --lock-path=/var/run/nginx.lock --http-client-body-temp-path=/var/cache/nginx/client_temp --http-proxy-temp-path=/var/cache/nginx/proxy_temp --http-fastcgi-temp-path=/var/cache/nginx/fastcgi_temp --http-uwsgi-temp-path=/var/cache/nginx/uwsgi_temp --http-scgi-temp-path=/var/cache/nginx/scgi_temp --user=nginx --group=nginx --with-compat --with-file-aio --with-threads --with-http_addition_module --with-http_auth_request_module --with-http_dav_module --with-http_flv_module --with-http_gunzip_module --with-http_gzip_static_module --with-http_mp4_module --with-http_random_index_module --with-http_realip_module --with-http_secure_link_module --with-http_slice_module --with-http_ssl_module --with-http_stub_status_module --with-http_sub_module --with-http_v2_module --with-mail --with-mail_ssl_module --with-stream --with-stream_realip_module --with-stream_ssl_module --with-stream_ssl_preread_module --with-cc-opt='-g -O2 -fdebug-prefix-map=/data/builder/debuild/nginx-1.18.0/debian/debuild-base/nginx-1.18.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -fPIC' --with-ld-opt='-Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-z,now -Wl,--as-needed -pie'
# gsm9go1o63-algo-1-dswgh | INFO:__main__:started nginx (pid: 14)
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: using the "epoll" event method
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: nginx/1.18.0
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: built by gcc 7.5.0 (Ubuntu 7.5.0-3ubuntu1~18.04)
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: OS: Linux 4.14.252-195.483.amzn2.x86_64
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: getrlimit(RLIMIT_NOFILE): 32768:65536
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: start worker processes
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: start worker process 15
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: start worker process 16
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: start worker process 17
# gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:28 [notice] 14#14: start worker process 18
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.361270: I tensorflow_serving/model_servers/server_core.cc:462] Adding/updating models.
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.361318: I tensorflow_serving/model_servers/server_core.cc:573]  (Re-)adding model: model
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.463084: I tensorflow_serving/util/retrier.cc:46] Retrying of Reserving resources for servable: {name: model version: 1} exhausted max_num_retries: 0
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.463115: I tensorflow_serving/core/basic_manager.cc:739] Successfully reserved resources to load servable {name: model version: 1}
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.463123: I tensorflow_serving/core/loader_harness.cc:66] Approving load for servable version {name: model version: 1}
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.463135: I tensorflow_serving/core/loader_harness.cc:74] Loading servable version {name: model version: 1}
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.463170: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:31] Reading SavedModel from: /opt/ml/model/1
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.465770: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:54] Reading meta graph with tags { serve }
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.465808: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:264] Reading SavedModel debug info (if present) from: /opt/ml/model/1
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.470681: I external/org_tensorflow/tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.472785: I external/org_tensorflow/tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.504970: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:203] Restoring SavedModel bundle.
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.611655: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:152] Running initialization op on SavedModel bundle at path: /opt/ml/model/1
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.617998: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:333] SavedModel load for tags { serve }; Status: success: OK. Took 154827 microseconds.
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.618558: I tensorflow_serving/servables/tensorflow/saved_model_warmup.cc:105] No warmup data file found at /opt/ml/model/1/assets.extra/tf_serving_warmup_requests
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.619035: I tensorflow_serving/util/retrier.cc:46] Retrying of Loading servable: {name: model version: 1} exhausted max_num_retries: 0
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.619058: I tensorflow_serving/core/loader_harness.cc:87] Successfully loaded servable version {name: model version: 1}
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.628841: I tensorflow_serving/model_servers/server.cc:362] Running gRPC ModelServer at 0.0.0.0:9000 ...
# gsm9go1o63-algo-1-dswgh | [warn] getaddrinfo: address family for nodename not supported
# gsm9go1o63-algo-1-dswgh | 2022-01-05 08:44:28.633610: I tensorflow_serving/model_servers/server.cc:382] Exporting HTTP/REST API at:localhost:8501 ...
# gsm9go1o63-algo-1-dswgh | [evhttp_server.cc : 238] NET_LOG: Entering the event loop ...
# gsm9go1o63-algo-1-dswgh | 172.18.0.1 - - [05/Jan/2022:08:44:31 +0000] "GET /ping HTTP/1.1" 200 0 "-" "python-urllib3/1.26.7"
# !gsm9go1o63-algo-1-dswgh | 2022/01/05 08:44:31 [info] 16#16: *1 client 172.18.0.1 closed keepalive connection

# %%
input = {
  'instances': np.random.rand(30).reshape(-1, 30)
}
result = local_predictor.predict(input)
result
# Out:
# {'predictions': [[0.48450315]]}
# gsm9go1o63-algo-1-dswgh | 172.18.0.1 - - [05/Jan/2022:08:44:31 +0000] "POST /invocations HTTP/1.1" 200 42 "-" "python-urllib3/1.26.7"

# %%
local_predictor.delete_endpoint()
# Out:
# Gracefully stopping... (press Ctrl+C again to force)

# %% [markdown]
# ### Managed training

# %%
from sagemaker.tensorflow import TensorFlow

model_dir = '/opt/ml/model'
instance_type = 'ml.c5.xlarge'
hyperparameters = {'epochs': 200, 'batch_size': 10, 'learning_rate': 0.001}

estimator = TensorFlow(source_dir='source_dir',
                       entry_point='tf_batch.py',
                       model_dir=model_dir,
                       instance_type=instance_type,
                       instance_count=1,
                       hyperparameters=hyperparameters,
                       role=sagemaker.get_execution_role(),
                       base_job_name='tf-batch-transform',
                       framework_version='2.1',
                       py_version='py3')

# %%
inputs = {'train': f's3://{bucket}/{prefix}/data/train',
          'validation': f's3://{bucket}/{prefix}/data/val'}

estimator.fit(inputs, wait=True)
# Out:
# 2022-01-05 08:44:42 Starting - Starting the training job...
# 2022-01-05 08:44:44 Starting - Launching requested ML instancesProfilerReport-1641372282: InProgress
# ...
# 2022-01-05 08:45:39 Starting - Preparing the instances for training............
# 2022-01-05 08:47:36 Downloading - Downloading input data
# 2022-01-05 08:47:36 Training - Downloading the training image...
# 2022-01-05 08:48:12 Training - Training image download completed. Training in progress.2022-01-05 08:47:55,349 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-01-05 08:47:55,355 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-05 08:47:55,791 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-05 08:47:55,807 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-05 08:47:55,820 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-05 08:47:55,830 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 10,
#         "model_dir": "/opt/ml/model",
#         "epochs": 200,
#         "learning_rate": 0.001
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tf-batch-transform-2022-01-05-08-44-41-974",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-889750940888/tf-batch-transform-2022-01-05-08-44-41-974/source/sourcedir.tar.gz",
#     "module_name": "tf_batch",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "tf_batch.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":10,"epochs":200,"learning_rate":0.001,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=tf_batch.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_batch
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-889750940888/tf-batch-transform-2022-01-05-08-44-41-974/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":10,"epochs":200,"learning_rate":0.001,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tf-batch-transform-2022-01-05-08-44-41-974","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-889750940888/tf-batch-transform-2022-01-05-08-44-41-974/source/sourcedir.tar.gz","module_name":"tf_batch","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"tf_batch.py"}
# SM_USER_ARGS=["--batch_size","10","--epochs","200","--learning_rate","0.001","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_SIZE=10
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=200
# SM_HP_LEARNING_RATE=0.001
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.6 tf_batch.py --batch_size 10 --epochs 200 --learning_rate 0.001 --model_dir /opt/ml/model
# x_train (451, 30) y_train (451,)
# x_validation (53, 30) y_validation (53,)
# /cpu:0
# batch_size = 10, epochs = 200, learning rate = 0.001
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                930
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,566
# Trainable params: 1,566
# Non-trainable params: 0
# _________________________________________________________________
# [2022-01-05 08:47:57.892 ip-10-0-162-69.ap-northeast-2.compute.internal:27 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-01-05 08:47:57.893 ip-10-0-162-69.ap-northeast-2.compute.internal:27 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-01-05 08:47:57.893 ip-10-0-162-69.ap-northeast-2.compute.internal:27 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2022-01-05 08:47:57.893 ip-10-0-162-69.ap-northeast-2.compute.internal:27 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# Train on 451 samples, validate on 53 samples
# Epoch 1/200
# [2022-01-05 08:47:57.987 ip-10-0-162-69.ap-northeast-2.compute.internal:27 INFO hook.py:398] Monitoring the collections: losses, sm_metrics, metrics
# #015 10/451 [..............................] - ETA: 31s - loss: 4.1962 - accuracy: 0.3000 - mse: 0.7181#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015130/451 [=======>......................] - ETA: 1s - loss: 1.0994 - accuracy: 0.5308 - mse: 0.3207 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015250/451 [===============>..............] - ETA: 0s - loss: 0.8996 - accuracy: 0.5600 - mse: 0.2840#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015390/451 [========================>.....] - ETA: 0s - loss: 0.8011 - accuracy: 0.5974 - mse: 0.2596#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015451/451 [==============================] - 1s 2ms/sample - loss: 0.7768 - accuracy: 0.5965 - mse: 0.2535 - val_loss: 0.6162 - val_accuracy: 0.6226 - val_mse: 0.2121
# Epoch 2/200
# #015 10/451 [..............................] - ETA: 0s - loss: 0.6928 - accuracy: 0.3000 - mse: 0.2499#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015140/451 [========>.....................] - ETA: 0s - loss: 0.6053 - accuracy: 0.6357 - mse: 0.2069#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015280/451 [=================>............] - ETA: 0s - loss: 0.6146 - accuracy: 0.5857 - mse: 0.2115#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015430/451 [===========================>..] - ETA: 0s - loss: 0.5935 - accuracy: 0.6209 - mse: 0.2015#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015451/451 [==============================] - 0s 421us/sample - loss: 0.5950 - accuracy: 0.6186 - mse: 0.2023 - val_loss: 0.5714 - val_accuracy: 0.6226 - val_mse: 0.1923
# Epoch 3/200
# #015 10/451 [..............................] - ETA: 0s - loss: 0.5581 - accuracy: 0.7000 - mse: 0.1854#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015160/451 [=========>....................] - ETA: 0s - loss: 0.4294 - accuracy: 0.8250 - mse: 0.1349#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015280/451 [=================>............] - ETA: 0s - loss: 0.3812 - accuracy: 0.8536 - mse: 0.1168#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015420/451 [==========================>...] - ETA: 0s - loss: 0.3490 - accuracy: 0.8667 - mse: 0.1061#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015451/451 [==============================] - 0s
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 2022-01-05 08:48:38,601 sagemaker-training-toolkit INFO     Reporting training SUCCESS

# %% [markdown]
# ---
# ## Batch Transform
#
# In SageMaker Batch Transform, we introduced 3 new attributes - **input_filter, join_source and output_filter**. In the below cell, we use the SageMaker Python SDK to kick-off several Batch Transform jobs using different configurations of these 3 new attributes. Please refer to this page to learn more about how to use them.

# %% [markdown]
# #### Prepare `inference.py`
# https://sagemaker.readthedocs.io/en/stable/frameworks/tensorflow/deploying_tensorflow_serving.html?highlight=inference.py

# %%
# %%writefile source_dir/inference.py
import json

def input_handler(data, context):
    """ Pre-process request input before it is sent to TensorFlow Serving REST API
    Args:
        data (obj): the request data, in format of dict or string
        context (Context): an object containing request and configuration details
    Returns:
        (dict): a JSON-serializable dict that contains request body and headers
    """
    if context.request_content_type == 'text/csv':
        request = data.read().decode('utf-8').rstrip('\n')
        request = [float(x) for x in request.split(',')]
        request.pop(0) # Remove "id" column
        request.pop(1) # Remove "diagnosis" column
        
        return json.dumps({
            'instances': [request]
        })

    raise ValueError('{{"error": "unsupported content type {}"}}'.format(
        context.request_content_type or "unknown"))


def output_handler(data, context):
    """Post-process TensorFlow Serving output before it is returned to the client.
    Args:
        data (obj): the TensorFlow serving response
        context (Context): an object containing request and configuration details
    Returns:
        (bytes, string): data to return to client, response content type
    """
    if data.status_code != 200:
        raise ValueError(data.content.decode('utf-8'))

    response_content_type = context.accept_header
    
    prediction = json.loads(data.content.decode("utf-8"))['predictions'][0][0]
    output = json.dumps({'predictions': prediction})

    return output, response_content_type

# %% [markdown]
# #### Create TensorflowModel from saved model artifacts

# %%
model_artefect_s3_location = estimator.model_data  #'s3://BUCKET/PREFIX/model.tar.gz'
model_artefect_s3_location

# %%
from sagemaker.tensorflow import TensorFlowModel

tf_model = TensorFlowModel(
    model_data=model_artefect_s3_location,
    role=role,
    framework_version="2.1.0",
    source_dir="source_dir",
    entry_point="inference.py",
)

sm_transformer = tf_model.transformer(
    instance_count=1,
#     instance_type='ml.c5.xlarge',
    instance_type='local',
    accept='text/csv',
    strategy='SingleRecord',   # MultiRecord|SingleRecord
    assemble_with='Line',
    output_path='s3://{}/{}/batch_transform'.format(bucket, prefix)
)

# %% [markdown]
# #### Batch inference

# %%
# input_location = 's3://{}/{}/data/batch/data_batch_single.csv'.format(bucket, prefix)
input_location = 's3://{}/{}/data/batch/data_batch.csv'.format(bucket, prefix)
input_location

# %%
# !aws s3 ls {input_location}

# %%
sm_transformer.transform(
    data=input_location,
    data_type='S3Prefix',
    content_type='text/csv',
    split_type='Line',         # None(default)|LIne|RecordID|TFRecord
#     input_filter='$[1:]',
#     join_source='Input',
#     output_filter='$',
    wait=True
)

# %% [markdown]
# #### Check Batch Transform results

# %%
batch_results_s3 = sm_transformer.output_path
batch_job_name = sm_transformer.latest_transform_job.job_name
batch_results_s3

# %%
batch_result_dir = os.path.join(os.getcwd(), 'batch')
os.makedirs(batch_result_dir, exist_ok=True)

# %%
# !aws s3 cp {batch_results_s3}/{batch_job_name} {batch_result_dir} --recursive
